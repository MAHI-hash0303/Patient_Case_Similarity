# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("/content/patient_details.csv")
df.head()
# Out:
#    PATIENT_ID FIRST_NAME   LAST_NAME  GENDER        DISEASE  \
# 0           1     Trudey     Postans  Female            flu
# 1           2  Alisander      Winser  Female      influenza
# 2           3     Helene     Crampsy  Female         cancer
# 3           4      Berta  Antonowicz  Female       diabetes
# 4           5     Leigha     Lowther  Female  heart disease
#
#                                             SYMPTOMS  \
# 0  Fever, chills, cough, sore throat, body aches,...
# 1  Similar to common cold symptoms but more sever...
# 2  unexplained weight loss, pain, fatigue, skin c...
# 3  Frequent urination, excessive thirst, unexplai...
# 4  Chest pain (angina), shortness of breath, fati...
#
#                                         PRESCRIPTION
# 0          Oseltamivir (Tamiflu), Zanamivir (Relenza
# 1          Oseltamivir (Tamiflu), Zanamivir (Relenza
# 2                 Paclitaxel, Doxorubicin, Cisplatin
# 3  Insulin (various types), Metformin, Glipizide,...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99626 entries, 0 to 99625
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PATIENT_ID    99626 non-null  int64
#  1   FIRST_NAME    99626 non-null  object
#  2   LAST_NAME     99626 non-null  object
#  3   GENDER        99626 non-null  object
#  4   DISEASE       99626 non-null  object
#  5   SYMPTOMS      99626 non-null  object
#  6   PRESCRIPTION  99626 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
df.shape
# Out:
# (99626, 7)

# %%
df.columns
# Out:
# Index(['PATIENT_ID', 'FIRST_NAME', 'LAST_NAME', 'GENDER', 'DISEASE',
#        'SYMPTOMS', 'PRESCRIPTION'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PATIENT_ID      0
# FIRST_NAME      0
# LAST_NAME       0
# GENDER          0
# DISEASE         0
# SYMPTOMS        0
# PRESCRIPTION    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# PATIENT_ID      0
# FIRST_NAME      0
# LAST_NAME       0
# GENDER          0
# DISEASE         0
# SYMPTOMS        0
# PRESCRIPTION    0
# dtype: int64

# %%
df['RECOVERY RATE'] = np.random.randint(1, 11, size=len(df))

# %%
df.head()
# Out:
#    PATIENT_ID FIRST_NAME   LAST_NAME  GENDER        DISEASE  \
# 0           1     Trudey     Postans  Female            flu
# 1           2  Alisander      Winser  Female      influenza
# 2           3     Helene     Crampsy  Female         cancer
# 3           4      Berta  Antonowicz  Female       diabetes
# 4           5     Leigha     Lowther  Female  heart disease
#
#                                             SYMPTOMS  \
# 0  Fever, chills, cough, sore throat, body aches,...
# 1  Similar to common cold symptoms but more sever...
# 2  unexplained weight loss, pain, fatigue, skin c...
# 3  Frequent urination, excessive thirst, unexplai...
# 4  Chest pain (angina), shortness of breath, fati...
#
#                                         PRESCRIPTION  RECOVERY RATE
# 0          Oseltamivir (Tamiflu), Zanamivir (Relenza              8
# 1          Oseltamivir (Tamiflu), Zanamivir (Relenza              5
# 2                 Paclitaxel, Doxorubicin, Cisplatin              6
# ...

# %%
start_row = 99626
end_row = 107519
df = df.drop(df.index[start_row:end_row+1])

# %%
df.isnull().sum()
# Out:
# PATIENT_ID       0
# FIRST_NAME       0
# LAST_NAME        0
# GENDER           0
# DISEASE          0
# SYMPTOMS         0
# PRESCRIPTION     0
# RECOVERY RATE    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# PATIENT_ID       0
# FIRST_NAME       0
# LAST_NAME        0
# GENDER           0
# DISEASE          0
# SYMPTOMS         0
# PRESCRIPTION     0
# RECOVERY RATE    0
# dtype: int64

# %%
threshold = 1000
categorical_columns = ['DISEASE', 'SYMPTOMS', 'PRESCRIPTION']
for col in categorical_columns:
    value_counts = df[col].value_counts()
    outliers = value_counts[value_counts < threshold].index.tolist()
    print(f"Outliers in '{col}': {outliers}")
# Out:
# Outliers in 'DISEASE': ['influenza', 'cancer', 'flu', 'diabetes']
# Outliers in 'SYMPTOMS': ['Similar to common cold symptoms but more severe, with fever, chills, body aches', 'unexplained weight loss, pain, fatigue, skin changes, and changes in bowel or bladder habits', 'Fever, chills, cough, sore throat, body aches, fatigue', 'Frequent urination, excessive thirst, unexplained weight loss, fatigue, blurred vision']
# Outliers in 'PRESCRIPTION': ['Paclitaxel, Doxorubicin, Cisplatin', 'Insulin (various types), Metformin, Glipizide, Sitagliptin']
